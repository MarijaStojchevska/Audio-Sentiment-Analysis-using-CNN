# %% [markdown]
# ## About the data

# %% [markdown]
# The dataset can be found [here](http://emodb.bilderbar.info/index-1280.html).
#
# It contains samples of emotional speech in German, labeled with one of 7 different emotions: Anger, Boredom, Disgust, Fear, Happiness, Sadness and Neutral.
#
# Please download the full database and refer to the documentation to understand how the samples are labeled (see "Additional information").

# %% [markdown]
# # Libraries Loading

# %%
# %matplotlib inline

import os
import argparse
import urllib.request
import zipfile36 as zipfile
from joblib import dump, load

import librosa
import numpy as np
import pandas as pd
import seaborn as sns
import librosa.display
import matplotlib.pyplot as plt

import sklearn
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Conv1D, MaxPooling1D, BatchNormalization, Dropout, Flatten, Dense

# %%
# Creates parser and defines arguments 
def flags():
    parser = argparse.ArgumentParser()

    parser.add_argument(
        '--dataset_url',
        type=str,
        default='http://emodb.bilderbar.info/download/download.zip',
        help='URL to access the dataset')
    
    parser.add_argument(
        '--source_path',
        type=str,
        default='./',
        help='path to the source directory')
    
    parser.add_argument(
        '--directory_name',
        type=str,
        default='emodb.zip',
        help='names the downloaded data directory')
    
    parser.add_argument(
        '--features_type',
        type=str,
        default='mfcc',
        help='training features [melspec, mfcc]')
    
    parser.add_argument(
        '--test_split',
        type=float,
        default=0.15,
        help='split percentages fot the test set')
    
    parser.add_argument(
        '--val_split',
        type=float,
        default=0.15,
        help='split percentages fot the validation set')
    
    parser.add_argument(
        '--learning_rate',
        type=float,
        default=1e-3,
        help='learning rate')
    
    parser.add_argument(
        '--batch_size',
        type=int,
        default=32,
        help='size of the training batch')
    
    parser.add_argument(
        '--num_epochs',
        type=int,
        default=200,
        help='number of training epochs')
    
    parser.add_argument(
        '--patience',
        type=int,
        default=20,
        help='early stopping patience')
    
    parser.add_argument(
        '--port_number',
        type=int,
        default=105,
        help='Flask API port')

        
    FLAGS, unparsed = parser.parse_known_args()
    return FLAGS, unparsed

# %% [markdown]
# # Feature Engineering & Modeling

# %%
def download_and_extract(source, src_dir, dir_name):
    # Download directory from url
    urllib.request.urlretrieve(source, dir_name)

    # Extract downloaded dataset directory
    source_zip = src_dir+dir_name
    dataset_dir = dir_name.split('.')[0]
    with zipfile.ZipFile(source_zip, 'r') as zip_ref:
        zip_ref.extractall(dataset_dir)
    return dataset_dir

# %%
def dataset_reading(src_dir, dataset_dir):
    audio_files = sorted(os.listdir(os.path.join(src_dir+dataset_dir, 'wav')))
    audio_directory = src_dir+dataset_dir+'/wav/'
    description = []
    for f in audio_files:
        description.append(f.split('.')[0])

    char_to_emotion = {
        'W': 'anger',
        'L': 'boredom',
        'E': 'disgust',
        'A': 'fear',
        'F': 'happiness',
        'T': 'sadness',
        'N': 'neutral',
    }
    emotions = []
    for d in description:
        emotions.append(char_to_emotion[d[5]])

    emotion_data = {"emotions": emotions}
    emotion_df = pd.DataFrame(emotion_data, index = audio_files)
    return audio_files, audio_directory, emotion_df, emotions

# %%
def class_histogram(emotion_df, emotions):
    # Count emotion occurrences
    print(emotion_df.emotions.value_counts())
    
    # Plot histogram of emotion occurrences
    plt.title('Emotion occurrences', size=16)
    sns.countplot(x=emotions)
    plt.xlabel('Emotion')
    plt.ylabel('Count')
    plt.show()

# %%
def zero_padding_or_cut(sound, avgLen):
    samples, sr = librosa.load(sound) 
    lenDifference = abs(len(samples)-avgLen)
    cutSize = addSize = int(lenDifference/2)
    
    if len(samples) < avgLen:
        # Padding with 0s
        zeros_front = [0] * addSize
        if lenDifference % 2 == 0:
            zeros_back = [0] * addSize
        else:
            zeros_back = [0] * (addSize+1)
        samples = np.concatenate((zeros_front, samples, zeros_back), axis=0)  
        
    elif len(samples) > avgLen:
        # Length cutting
        remaining = samples[cutSize:]
        if lenDifference % 2 == 0:
            samples = remaining[:len(remaining)-cutSize]
        else:
            samples = remaining[:len(remaining)-cutSize-1]
    return samples, sr

def audio_to_melspec(samples, sr):
    # Plot raw audio file
    pd.Series(samples).plot(figsize=(10, 5))
    plt.xlabel('Time Domain')
    plt.ylabel('Amplitude')
    #plt.show()
    # Create audio spectogram
    spectogram = librosa.stft(samples)
    # Represent frequency on a mel scale
    mag, phase = librosa.magphase(spectogram)
    mel_scaled_spec = librosa.feature.melspectrogram(S=mag, sr=sr)
    # Represent amplitude on a decibel scale
    decibel_scaled_spec = librosa.amplitude_to_db(S=mel_scaled_spec, ref=np.min)  
    return decibel_scaled_spec

def avg_audio_length(audio_files, audio_directory):
    sound_lengths = []
    for f in audio_files:
        sound = audio_directory+f
        samples, _ = librosa.load(sound)
        sound_lengths.append(len(samples))
    avgLen = int(np.mean(sound_lengths))
    return avgLen

def extract_melspec(samples, sr):
    melspec_val = np.mean(audio_to_melspec(samples, sr).T, axis=0)
    return melspec_val

def extract_mfcc(samples, sr):
    mfcc_val = np.mean(librosa.feature.mfcc(y=samples, sr=sr, n_mfcc=40).T, axis=0)
    return mfcc_val

# %%
def data_generator(audio_files, audio_directory, features_type):
    data=[]
    avgLen = avg_audio_length(audio_files, audio_directory)
    
    for f in audio_files:
        sound = audio_directory+f
                
        # Length transformation
        samples, sr = zero_padding_or_cut(sound, avgLen)
        
        # Feature extraction
        if features_type == 'mfcc':
            values = extract_mfcc(samples, sr)
        else:
            values = extract_melspec(samples, sr)
        
        data.append(values)
    return data

def labels_generator(emotion_df):
    labels = emotion_df['emotions'].values
    encoder = OneHotEncoder()
    labels = encoder.fit_transform(np.array(labels).reshape(-1,1)).toarray()
    return labels, encoder

# %%
# Prepate dataset for deep-learning
def dataset_split(audio_files, audio_directory, features_type, emotion_df, test_split, val_split):
    data = data_generator(audio_files, audio_directory, features_type)
    data = pd.DataFrame(data).iloc[:,:].values
    labels, encoder = labels_generator(emotion_df)
    print(labels.shape, data.shape)

    data, X_test, labels, Y_test = train_test_split(data, labels, test_size=test_split, stratify=labels, shuffle = True)
    X_train, X_val, Y_train, Y_val = train_test_split(data, labels, test_size=val_split, stratify=labels, shuffle=True)
    print(X_train.shape, Y_train.shape, X_test.shape, Y_test.shape, X_val.shape, Y_val.shape)

    X_train = np.expand_dims(X_train, axis=2)
    X_test = np.expand_dims(X_test, axis=2)
    X_val = np.expand_dims(X_val, axis=2)
    return X_train, X_test, Y_train, Y_test, X_val, Y_val, encoder

# %%
def CNN(X_train, Y_train, X_val, Y_val, batch_size, learning_rate, num_epochs, patience):
    # Define model type
    model = Sequential()
    
    # Define layers
    model.add(Conv1D(filters=64, kernel_size=5, padding="same",activation="relu", input_shape=(X_train.shape[1],1)))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.2))
    
    model.add(Conv1D(filters=125, kernel_size=10, padding="same",activation="relu"))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.2))

    model.add(Conv1D(filters=64, kernel_size=5, padding="same",activation="relu"))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.2))

    model.add(Flatten())
    model.add(Dense(7, activation="relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Dense(7, activation="softmax"))
    
    # Model configuration
    model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),  metrics=['accuracy'])
    model.summary()

    # Model training
    early_stopping = EarlyStopping(monitor='val_loss', mode='min', verbose=0, patience=patience)
    history = model.fit(x=X_train, y=Y_train, batch_size=batch_size, epochs=num_epochs, validation_data=(X_val, Y_val), callbacks=[early_stopping], verbose=2)
    return model, history

def evaluate(model, history, encoder, X_train, X_test, Y_train, Y_test, X_val, Y_val):
    # Model evaluation
    _, train_accuracy = model.evaluate(X_train, Y_train)
    _, val_accuracy = model.evaluate(X_val, Y_val)
    _, test_accuracy = model.evaluate(X_test, Y_test)
    
    print('Train accuracy: %.3f, Validation accuracy: %.3f, Test accuracy: %.3f'  % (train_accuracy, val_accuracy, test_accuracy))
    # Plot training and validation loss
    plt.plot(history.history['loss'], label='train')
    plt.plot(history.history['val_loss'], label='validation')
    plt.title('Model Loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend()
    plt.show()
    
    # Plot training and validation accuracy
    plt.plot(history.history['accuracy'], label='train')
    plt.plot(history.history['val_accuracy'], label='validation')
    plt.title('Model Accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend()
    plt.show()

    # Labels prediction
    predicted_values = model.predict(X_test)
    Y_pred = encoder.inverse_transform(predicted_values)
    Y_test = encoder.inverse_transform(Y_test)
    print(classification_report(Y_test, Y_pred))
    
def save_model(model, src_dir):
    # Save last trained model
    model.save(src_dir+'my_model')

# %% [markdown]
# # Results & Visualizations

# %%
def main():    
    # Get arguments
    FLAGS, unparsed = flags()
    source = FLAGS.dataset_url
    src_dir = FLAGS.source_path
    dir_name = FLAGS.directory_name
    features_type = FLAGS.features_type
    test_split = FLAGS.test_split
    val_split = FLAGS.val_split
    batch_size = FLAGS.batch_size
    learning_rate = FLAGS.learning_rate
    num_epochs = FLAGS.num_epochs
    patience = FLAGS.patience
    
    # Download and extract dataset
    dataset_dir = download_and_extract(source, src_dir, dir_name)
    # Dataset reading
    audio_files, audio_directory, emotion_df, emotions = dataset_reading(src_dir, dataset_dir)
    # Plot class distribution histogam
    class_histogram(emotion_df, emotions)
    # Prepare dataset for deep-learning
    X_train, X_test, Y_train, Y_test, X_val, Y_val, encoder = dataset_split(audio_files, audio_directory, features_type, emotion_df, test_split, val_split)
    # Save the one-hot encoder
    dump(encoder, 'encoder.joblib')
    
    # Implement and train CNN for SER
    model, history = CNN(X_train, Y_train, X_val, Y_val, batch_size, learning_rate, num_epochs, patience)
    # Model evaluation + results plotting
    evaluate(model, history, encoder, X_train, X_test, Y_train, Y_test, X_val, Y_val)
    # Save model
    save_model(model, src_dir)
    

if __name__ == "__main__":
    main()
# Out:
# anger        127
# boredom       81
# neutral       79
# happiness     71
# fear          69
# sadness       62
# disgust       46
# Name: emotions, dtype: int64
# (535, 7) (535, 40)
# (385, 40) (385, 7) (81, 40) (81, 7) (69, 40) (69, 7)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 40, 64)            384
#
#  batch_normalization (BatchN  (None, 40, 64)           256
#  ormalization)
#
#  max_pooling1d (MaxPooling1D  (None, 20, 64)           0
#  )
#
#  dropout (Dropout)           (None, 20, 64)            0
#
#  conv1d_1 (Conv1D)           (None, 20, 125)           80125
#
#  batch_normalization_1 (Batc  (None, 20, 125)          500
#  hNormalization)
#
#  max_pooling1d_1 (MaxPooling  (None, 10, 125)          0
#  1D)
#
#  dropout_1 (Dropout)         (None, 10, 125)           0
#
#  conv1d_2 (Conv1D)           (None, 10, 64)            40064
#
#  batch_normalization_2 (Batc  (None, 10, 64)           256
#  hNormalization)
#
#  max_pooling1d_2 (MaxPooling  (None, 5, 64)            0
#  1D)
#
#  dropout_2 (Dropout)         (None, 5, 64)             0
#
#  flatten (Flatten)           (None, 320)               0
#
#  dense (Dense)               (None, 7)                 2247
#
#  batch_normalization_3 (Batc  (None, 7)                28
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 7)                 0
#
#  dense_1 (Dense)             (None, 7)                 56
#
# =================================================================
# Total params: 123,916
# Trainable params: 123,396
# Non-trainable params: 520
# _________________________________________________________________
# Epoch 1/200
# 13/13 - 1s - loss: 2.0991 - accuracy: 0.1766 - val_loss: 5.5483 - val_accuracy: 0.1449 - 1s/epoch - 78ms/step
# Epoch 2/200
# 13/13 - 0s - loss: 1.8893 - accuracy: 0.2234 - val_loss: 4.3464 - val_accuracy: 0.1449 - 102ms/epoch - 8ms/step
# Epoch 3/200
# 13/13 - 0s - loss: 1.7552 - accuracy: 0.2727 - val_loss: 3.5733 - val_accuracy: 0.1594 - 103ms/epoch - 8ms/step
# Epoch 4/200
# 13/13 - 0s - loss: 1.7541 - accuracy: 0.2494 - val_loss: 3.1679 - val_accuracy: 0.2029 - 104ms/epoch - 8ms/step
# Epoch 5/200
# 13/13 - 0s - loss: 1.6439 - accuracy: 0.3013 - val_loss: 2.7092 - val_accuracy: 0.2029 - 104ms/epoch - 8ms/step
# Epoch 6/200
# 13/13 - 0s - loss: 1.6680 - accuracy: 0.2597 - val_loss: 2.4116 - val_accuracy: 0.1884 - 109ms/epoch - 8ms/step
# Epoch 7/200
# 13/13 - 0s - loss: 1.5952 - accuracy: 0.2961 - val_loss: 2.0923 - val_accuracy: 0.2464 - 105ms/epoch - 8ms/step
# Epoch 8/200
# 13/13 - 0s - loss: 1.5704 - accuracy: 0.3273 - val_loss: 1.8384 - val_accuracy: 0.2754 - 113ms/epoch - 9ms/step
# Epoch 9/200
# 13/13 - 0s - loss: 1.5370 - accuracy: 0.3377 - val_loss: 1.6525 - val_accuracy: 0.2899 - 106ms/epoch - 8ms/step
# Epoch 10/200
# 13/13 - 0s - loss: 1.5488 - accuracy: 0.3429 - val_loss: 1.4500 - val_accuracy: 0.3623 - 113ms/epoch - 9ms/step
# Epoch 11/200
# 13/13 - 0s - loss: 1.4985 - accuracy: 0.3922 - val_loss: 1.6175 - val_accuracy: 0.2899 - 107ms/epoch - 8ms/step
# Epoch 12/200
# 13/13 - 0s - loss: 1.4720 - accuracy: 0.4000 - val_loss: 1.5911 - val_accuracy: 0.2609 - 118ms/epoch - 9ms/step
# Epoch 13/200
# 13/13 - 0s - loss: 1.4746 - accuracy: 0.4104 - val_loss: 1.3713 - val_accuracy: 0.4348 - 106ms/epoch - 8ms/step
# Epoch 14/200
# 13/13 - 0s - loss: 1.4262 - accuracy: 0.4234 - val_loss: 1.3431 - val_accuracy: 0.4928 - 106ms/epoch - 8ms/step
# Epoch 15/200
# 13/13 - 0s - loss: 1.4321 - accuracy: 0.4130 - val_loss: 1.3308 - val_accuracy: 0.5072 - 108ms/epoch - 8ms/step
# Epoch 16/200
# 13/13 - 0s - loss: 1.3507 - accuracy: 0.4857 - val_loss: 1.2854 - val_accuracy: 0.5507 - 105ms/epoch - 8ms/step
# Epoch 17/200
# 13/13 - 0s - loss: 1.3536 - accuracy: 0.4883 - val_loss: 1.2007 - val_accuracy: 0.6377 - 104ms/epoch - 8ms/step
# Epoch 18/200
# 13/13 - 0s - loss: 1.3772 - accuracy: 0.4935 - val_loss: 1.1818 - val_accuracy: 0.5942 - 110ms/epoch - 8ms/step
# Epoch 19/200
# 13/13 - 0s - loss: 1.3378 - accuracy: 0.5143 - val_loss: 1.1392 - val_accuracy: 0.5797 - 107ms/epoch - 8ms/step
# Epoch 20/200
# 13/13 - 0s - loss: 1.3239 - accuracy: 0.4987 - val_loss: 1.1787 - val_accuracy: 0.5507 - 106ms/epoch - 8ms/step
# Epoch 21/200
# 13/13 - 0s - loss: 1.2916 - accuracy: 0.4961 - val_loss: 1.1789 - val_accuracy: 0.6087 - 109ms/epoch - 8ms/step
# Epoch 22/200
# 13/13 - 0s - loss: 1.2838 - accuracy: 0.5299 - val_loss: 1.1226 - val_accuracy: 0.6377 - 105ms/epoch - 8ms/step
# Epoch 23/200
# 13/13 - 0s - loss: 1.2617 - accuracy: 0.5429 - val_loss: 1.0753 - val_accuracy: 0.6667 - 103ms/epoch - 8ms/step
# Epoch 24/200
# 13/13 - 0s - loss: 1.2442 - accuracy: 0.5403 - val_loss: 1.0638 - val_accuracy: 0.6522 - 104ms/epoch - 8ms/step
# Epoch 25/200
# 13/13 - 0s - loss: 1.2400 - accuracy: 0.5403 - val_loss: 1.0551 - val_accuracy: 0.6232 - 107ms/epoch - 8ms/step
# Epoch 26/200
# 13/13 - 0s - loss: 1.2262 - accuracy: 0.5481 - val_loss: 1.0646 - val_accuracy: 0.6377 - 104ms/epoch - 8ms/step
# Epoch 27/200
# 13/13 - 0s - loss: 1.1746 - accuracy: 0.5584 - val_loss: 1.0638 - val_accuracy: 0.6232 - 103ms/epoch - 8ms/step
# Epoch 28/200
# 13/13 - 0s - loss: 1.1856 - accuracy: 0.5714 - val_loss: 1.0317 - val_accuracy: 0.6667 - 103ms/epoch - 8ms/step
# Epoch 29/200
# 13/13 - 0s - loss: 1.1176 - accuracy: 0.5896 - val_loss: 0.9974 - val_accuracy: 0.6232 - 101ms/epoch - 8ms/step
# Epoch 30/200
# 13/13 - 0s - loss: 1.1698 - accuracy: 0.5351 - val_loss: 0.9682 - val_accuracy: 0.6377 - 100ms/epoch - 8ms/step
# Epoch 31/200
# 13/13 - 0s - loss: 1.1415 - accuracy: 0.5636 - val_loss: 0.9414 - val_accuracy: 0.6522 - 103ms/epoch - 8ms/step
# Epoch 32/200
# 13/13 - 0s - loss: 1.1082 - accuracy: 0.6208 - val_loss: 0.9319 - val_accuracy: 0.6812 - 107ms/epoch - 8ms/step
# Epoch 33/200
# 13/13 - 0s - loss: 1.0809 - accuracy: 0.5662 - val_loss: 0.9238 - val_accuracy: 0.6812 - 104ms/epoch - 8ms/step
# Epoch 34/200
# 13/13 - 0s - loss: 1.0999 - accuracy: 0.5870 - val_loss: 0.9192 - val_accuracy: 0.7536 - 117ms/epoch - 9ms/step
# Epoch 35/200
# 13/13 - 0s - loss: 1.1161 - accuracy: 0.5688 - val_loss: 0.8666 - val_accuracy: 0.7536 - 104ms/epoch - 8ms/step
# Epoch 36/200
# 13/13 - 0s - loss: 1.0806 - accuracy: 0.6130 - val_loss: 0.8507 - val_accuracy: 0.7536 - 104ms/epoch - 8ms/step
# Epoch 37/200
# 13/13 - 0s - loss: 1.0535 - accuracy: 0.5974 - val_loss: 0.8784 - val_accuracy: 0.6957 - 103ms/epoch - 8ms/step
# Epoch 38/200
# 13/13 - 0s - loss: 1.0917 - accuracy: 0.6000 - val_loss: 0.8332 - val_accuracy: 0.7246 - 106ms/epoch - 8ms/step
# Epoch 39/200
# 13/13 - 0s - loss: 1.0648 - accuracy: 0.5714 - val_loss: 0.8091 - val_accuracy: 0.7246 - 103ms/epoch - 8ms/step
# Epoch 40/200
# 13/13 - 0s - loss: 1.0075 - accuracy: 0.6338 - val_loss: 0.8240 - val_accuracy: 0.7101 - 105ms/epoch - 8ms/step
# Epoch 41/200
# 13/13 - 0s - loss: 0.9989 - accuracy: 0.6208 - val_loss: 0.8002 - val_accuracy: 0.7246 - 131ms/epoch - 10ms/step
# Epoch 42/200
# 13/13 - 0s - loss: 1.0367 - accuracy: 0.6052 - val_loss: 0.8134 - val_accuracy: 0.6957 - 121ms/epoch - 9ms/step
# Epoch 43/200
# 13/13 - 0s - loss: 0.9837 - accuracy: 0.6545 - val_loss: 0.8012 - val_accuracy: 0.7391 - 105ms/epoch - 8ms/step
# Epoch 44/200
# 13/13 - 0s - loss: 1.0104 - accuracy: 0.6130 - val_loss: 0.8127 - val_accuracy: 0.6957 - 115ms/epoch - 9ms/step
# Epoch 45/200
# 13/13 - 0s - loss: 0.9585 - accuracy: 0.6649 - val_loss: 0.7669 - val_accuracy: 0.7971 - 106ms/epoch - 8ms/step
# Epoch 46/200
# 13/13 - 0s - loss: 0.9571 - accuracy: 0.6649 - val_loss: 0.7615 - val_accuracy: 0.7681 - 102ms/epoch - 8ms/step
# Epoch 47/200
# 13/13 - 0s - loss: 0.9328 - accuracy: 0.6883 - val_loss: 0.7597 - val_accuracy: 0.7101 - 105ms/epoch - 8ms/step
# Epoch 48/200
# 13/13 - 0s - loss: 0.9753 - accuracy: 0.6545 - val_loss: 0.6872 - val_accuracy: 0.7681 - 101ms/epoch - 8ms/step
# Epoch 49/200
# 13/13 - 0s - loss: 0.9322 - accuracy: 0.6390 - val_loss: 0.7417 - val_accuracy: 0.7391 - 108ms/epoch - 8ms/step
# Epoch 50/200
# 13/13 - 0s - loss: 0.9186 - accuracy: 0.6701 - val_loss: 0.6988 - val_accuracy: 0.7536 - 104ms/epoch - 8ms/step
# Epoch 51/200
# 13/13 - 0s - loss: 0.9407 - accuracy: 0.6416 - val_loss: 0.7193 - val_accuracy: 0.8261 - 112ms/epoch - 9ms/step
# Epoch 52/200
# 13/13 - 0s - loss: 0.9213 - accuracy: 0.6468 - val_loss: 0.6549 - val_accuracy: 0.7826 - 106ms/epoch - 8ms/step
# Epoch 53/200
# 13/13 - 0s - loss: 0.8756 - accuracy: 0.6805 - val_loss: 0.6309 - val_accuracy: 0.8406 - 115ms/epoch - 9ms/step
# Epoch 54/200
# 13/13 - 0s - loss: 0.8712 - accuracy: 0.6987 - val_loss: 0.6598 - val_accuracy: 0.8406 - 107ms/epoch - 8ms/step
# Epoch 55/200
# 13/13 - 0s - loss: 0.8469 - accuracy: 0.7039 - val_loss: 0.6653 - val_accuracy: 0.7971 - 105ms/epoch - 8ms/step
# Epoch 56/200
# 13/13 - 0s - loss: 0.8679 - accuracy: 0.7169 - val_loss: 0.6259 - val_accuracy: 0.8406 - 104ms/epoch - 8ms/step
# Epoch 57/200
# 13/13 - 0s - loss: 0.8133 - accuracy: 0.7091 - val_loss: 0.5975 - val_accuracy: 0.8406 - 103ms/epoch - 8ms/step
# Epoch 58/200
# 13/13 - 0s - loss: 0.7624 - accuracy: 0.7299 - val_loss: 0.6244 - val_accuracy: 0.8261 - 104ms/epoch - 8ms/step
# Epoch 59/200
# 13/13 - 0s - loss: 0.8441 - accuracy: 0.6831 - val_loss: 0.6329 - val_accuracy: 0.8116 - 103ms/epoch - 8ms/step
# Epoch 60/200
# 13/13 - 0s - loss: 0.8226 - accuracy: 0.7117 - val_loss: 0.6313 - val_accuracy: 0.8261 - 105ms/epoch - 8ms/step
# Epoch 61/200
# 13/13 - 0s - loss: 0.7963 - accuracy: 0.7013 - val_loss: 0.6536 - val_accuracy: 0.8116 - 105ms/epoch - 8ms/step
# Epoch 62/200
# 13/13 - 0s - loss: 0.8090 - accuracy: 0.7403 - val_loss: 0.6403 - val_accuracy: 0.8551 - 105ms/epoch - 8ms/step
# Epoch 63/200
# 13/13 - 0s - loss: 0.7698 - accuracy: 0.7039 - val_loss: 0.6376 - val_accuracy: 0.7681 - 116ms/epoch - 9ms/step
# Epoch 64/200
# 13/13 - 0s - loss: 0.7525 - accuracy: 0.7455 - val_loss: 0.5863 - val_accuracy: 0.8406 - 104ms/epoch - 8ms/step
# Epoch 65/200
# 13/13 - 0s - loss: 0.7688 - accuracy: 0.7455 - val_loss: 0.6619 - val_accuracy: 0.7536 - 105ms/epoch - 8ms/step
# Epoch 66/200
# 13/13 - 0s - loss: 0.7478 - accuracy: 0.7221 - val_loss: 0.5852 - val_accuracy: 0.7681 - 102ms/epoch - 8ms/step
# Epoch 67/200
# 13/13 - 0s - loss: 0.6560 - accuracy: 0.8026 - val_loss: 0.5899 - val_accuracy: 0.7536 - 103ms/epoch - 8ms/step
# Epoch 68/200
# 13/13 - 0s - loss: 0.7560 - accuracy: 0.7039 - val_loss: 0.5998 - val_accuracy: 0.7971 - 103ms/epoch - 8ms/step
# Epoch 69/200
# 13/13 - 0s - loss: 0.7425 - accuracy: 0.7221 - val_loss: 0.5376 - val_accuracy: 0.8406 - 104ms/epoch - 8ms/step
# Epoch 70/200
# 13/13 - 0s - loss: 0.7296 - accuracy: 0.7506 - val_loss: 0.5255 - val_accuracy: 0.8696 - 113ms/epoch - 9ms/step
# Epoch 71/200
# 13/13 - 0s - loss: 0.6615 - accuracy: 0.7481 - val_loss: 0.5314 - val_accuracy: 0.8406 - 107ms/epoch - 8ms/step
# Epoch 72/200
# 13/13 - 0s - loss: 0.6894 - accuracy: 0.7506 - val_loss: 0.5525 - val_accuracy: 0.8116 - 114ms/epoch - 9ms/step
# Epoch 73/200
# 13/13 - 0s - loss: 0.6638 - accuracy: 0.7688 - val_loss: 0.4699 - val_accuracy: 0.8261 - 113ms/epoch - 9ms/step
# Epoch 74/200
# 13/13 - 0s - loss: 0.6134 - accuracy: 0.7896 - val_loss: 0.5337 - val_accuracy: 0.8116 - 115ms/epoch - 9ms/step
# Epoch 75/200
# 13/13 - 0s - loss: 0.6409 - accuracy: 0.7455 - val_loss: 0.4930 - val_accuracy: 0.8841 - 115ms/epoch - 9ms/step
# Epoch 76/200
# 13/13 - 0s - loss: 0.6538 - accuracy: 0.7636 - val_loss: 0.4751 - val_accuracy: 0.8696 - 111ms/epoch - 9ms/step
# Epoch 77/200
# 13/13 - 0s - loss: 0.6093 - accuracy: 0.8052 - val_loss: 0.5510 - val_accuracy: 0.8261 - 103ms/epoch - 8ms/step
# Epoch 78/200
# 13/13 - 0s - loss: 0.5908 - accuracy: 0.8026 - val_loss: 0.4663 - val_accuracy: 0.8696 - 118ms/epoch - 9ms/step
# Epoch 79/200
# 13/13 - 0s - loss: 0.6533 - accuracy: 0.7481 - val_loss: 0.4482 - val_accuracy: 0.8696 - 109ms/epoch - 8ms/step
# Epoch 80/200
# 13/13 - 0s - loss: 0.6330 - accuracy: 0.7948 - val_loss: 0.4384 - val_accuracy: 0.8551 - 104ms/epoch - 8ms/step
# Epoch 81/200
# 13/13 - 0s - loss: 0.6027 - accuracy: 0.7792 - val_loss: 0.4304 - val_accuracy: 0.8986 - 104ms/epoch - 8ms/step
# Epoch 82/200
# 13/13 - 0s - loss: 0.5569 - accuracy: 0.8338 - val_loss: 0.4507 - val_accuracy: 0.8841 - 106ms/epoch - 8ms/step
# Epoch 83/200
# 13/13 - 0s - loss: 0.5852 - accuracy: 0.7974 - val_loss: 0.4442 - val_accuracy: 0.8551 - 103ms/epoch - 8ms/step
# Epoch 84/200
# 13/13 - 0s - loss: 0.5456 - accuracy: 0.8130 - val_loss: 0.4681 - val_accuracy: 0.8696 - 104ms/epoch - 8ms/step
# Epoch 85/200
# 13/13 - 0s - loss: 0.5800 - accuracy: 0.8000 - val_loss: 0.4712 - val_accuracy: 0.8841 - 109ms/epoch - 8ms/step
# Epoch 86/200
# 13/13 - 0s - loss: 0.5056 - accuracy: 0.8468 - val_loss: 0.4275 - val_accuracy: 0.8841 - 102ms/epoch - 8ms/step
# Epoch 87/200
# 13/13 - 0s - loss: 0.5448 - accuracy: 0.8026 - val_loss: 0.5072 - val_accuracy: 0.8551 - 105ms/epoch - 8ms/step
# Epoch 88/200
# 13/13 - 0s - loss: 0.5715 - accuracy: 0.7870 - val_loss: 0.4801 - val_accuracy: 0.8406 - 104ms/epoch - 8ms/step
# Epoch 89/200
# 13/13 - 0s - loss: 0.5666 - accuracy: 0.7922 - val_loss: 0.5102 - val_accuracy: 0.8261 - 117ms/epoch - 9ms/step
# Epoch 90/200
# 13/13 - 0s - loss: 0.5589 - accuracy: 0.8364 - val_loss: 0.4775 - val_accuracy: 0.8551 - 105ms/epoch - 8ms/step
# Epoch 91/200
# 13/13 - 0s - loss: 0.5809 - accuracy: 0.7662 - val_loss: 0.4083 - val_accuracy: 0.8696 - 103ms/epoch - 8ms/step
# Epoch 92/200
# 13/13 - 0s - loss: 0.4677 - accuracy: 0.8182 - val_loss: 0.4308 - val_accuracy: 0.8696 - 103ms/epoch - 8ms/step
# Epoch 93/200
# 13/13 - 0s - loss: 0.5147 - accuracy: 0.8286 - val_loss: 0.4527 - val_accuracy: 0.8696 - 106ms/epoch - 8ms/step
# Epoch 94/200
# 13/13 - 0s - loss: 0.5057 - accuracy: 0.8260 - val_loss: 0.4481 - val_accuracy: 0.8261 - 104ms/epoch - 8ms/step
# Epoch 95/200
# 13/13 - 0s - loss: 0.5264 - accuracy: 0.8078 - val_loss: 0.4031 - val_accuracy: 0.8841 - 101ms/epoch - 8ms/step
# Epoch 96/200
# 13/13 - 0s - loss: 0.4463 - accuracy: 0.8571 - val_loss: 0.4475 - val_accuracy: 0.8841 - 107ms/epoch - 8ms/step
# Epoch 97/200
# 13/13 - 0s - loss: 0.4499 - accuracy: 0.8494 - val_loss: 0.3939 - val_accuracy: 0.8696 - 121ms/epoch - 9ms/step
# Epoch 98/200
# 13/13 - 0s - loss: 0.4537 - accuracy: 0.8468 - val_loss: 0.4617 - val_accuracy: 0.8551 - 106ms/epoch - 8ms/step
# Epoch 99/200
# 13/13 - 0s - loss: 0.4842 - accuracy: 0.8130 - val_loss: 0.4509 - val_accuracy: 0.8696 - 104ms/epoch - 8ms/step
# Epoch 100/200
# 13/13 - 0s - loss: 0.4607 - accuracy: 0.8545 - val_loss: 0.4373 - val_accuracy: 0.8116 - 105ms/epoch - 8ms/step
# Epoch 101/200
# 13/13 - 0s - loss: 0.4850 - accuracy: 0.8286 - val_loss: 0.4393 - val_accuracy: 0.8696 - 102ms/epoch - 8ms/step
# Epoch 102/200
# 13/13 - 0s - loss: 0.4281 - accuracy: 0.8597 - val_loss: 0.4479 - val_accuracy: 0.8261 - 105ms/epoch - 8ms/step
# Epoch 103/200
# 13/13 - 0s - loss: 0.4388 - accuracy: 0.8597 - val_loss: 0.4205 - val_accuracy: 0.8841 - 125ms/epoch - 10ms/step
# Epoch 104/200
# 13/13 - 0s - loss: 0.4323 - accuracy: 0.8571 - val_loss: 0.4914 - val_accuracy: 0.8551 - 112ms/epoch - 9ms/step
# Epoch 105/200
# 13/13 - 0s - loss: 0.4472 - accuracy: 0.8130 - val_loss: 0.4923 - val_accuracy: 0.8406 - 106ms/epoch - 8ms/step
# Epoch 106/200
# 13/13 - 0s - loss: 0.4397 - accuracy: 0.8597 - val_loss: 0.4578 - val_accuracy: 0.8696 - 107ms/epoch - 8ms/step
# Epoch 107/200
# 13/13 - 0s - loss: 0.4490 - accuracy: 0.8675 - val_loss: 0.4526 - val_accuracy: 0.8696 - 108ms/epoch - 8ms/step
# Epoch 108/200
# 13/13 - 0s - loss: 0.4597 - accuracy: 0.8260 - val_loss: 0.5150 - val_accuracy: 0.8406 - 101ms/epoch - 8ms/step
# Epoch 109/200
# 13/13 - 0s - loss: 0.4208 - accuracy: 0.8364 - val_loss: 0.5038 - val_accuracy: 0.8551 - 105ms/epoch - 8ms/step
# Epoch 110/200
# 13/13 - 0s - loss: 0.4139 - accuracy: 0.8675 - val_loss: 0.4806 - val_accuracy: 0.8116 - 102ms/epoch - 8ms/step
# Epoch 111/200
# 13/13 - 0s - loss: 0.4282 - accuracy: 0.8519 - val_loss: 0.5063 - val_accuracy: 0.8696 - 101ms/epoch - 8ms/step
# Epoch 112/200
# 13/13 - 0s - loss: 0.4449 - accuracy: 0.8286 - val_loss: 0.5313 - val_accuracy: 0.8696 - 104ms/epoch - 8ms/step
# Epoch 113/200
# 13/13 - 0s - loss: 0.4126 - accuracy: 0.8442 - val_loss: 0.5268 - val_accuracy: 0.8406 - 105ms/epoch - 8ms/step
# Epoch 114/200
# 13/13 - 0s - loss: 0.4189 - accuracy: 0.8623 - val_loss: 0.4825 - val_accuracy: 0.8551 - 102ms/epoch - 8ms/step
# Epoch 115/200
# 13/13 - 0s - loss: 0.4305 - accuracy: 0.8519 - val_loss: 0.4458 - val_accuracy: 0.8551 - 103ms/epoch - 8ms/step
# Epoch 116/200
# 13/13 - 0s - loss: 0.4454 - accuracy: 0.8234 - val_loss: 0.5101 - val_accuracy: 0.8696 - 101ms/epoch - 8ms/step
# Epoch 117/200
# 13/13 - 0s - loss: 0.3798 - accuracy: 0.8649 - val_loss: 0.4730 - val_accuracy: 0.8841 - 105ms/epoch - 8ms/step
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0530 - accuracy: 1.0000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4730 - accuracy: 0.8841
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6662 - accuracy: 0.7407
# Train accuracy: 1.000, Validation accuracy: 0.884, Test accuracy: 0.741
# 3/3 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#        anger       0.76      1.00      0.86        19
#      boredom       0.70      0.58      0.64        12
#      disgust       0.75      0.43      0.55         7
#         fear       0.78      0.64      0.70        11
#    happiness       0.78      0.64      0.70        11
#      neutral       0.61      0.92      0.73        12
#      sadness       1.00      0.67      0.80         9
#
#     accuracy                           0.74        81
#    macro avg       0.77      0.70      0.71        81
# weighted avg       0.76      0.74      0.73        81
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./my_model/assets
# INFO:tensorflow:Assets written to: ./my_model/assets
